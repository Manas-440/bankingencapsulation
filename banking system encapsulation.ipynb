# %%
class bank_account:
    def __init__(self,c_name,mob,dob,account,balance):
        self.__c_name=c_name
        self.__mob=mob
        self.__dob=dob
        self.__account=account
        self.__balance=balance
    def detail(self):
        return self.__c_name,self.__mob,self.__dob,self.__account,self.__balance
    def add(self,amount):                                                                                                                                                                                                                                                                                                                                                                                                         
        self.__balance=self.__balance+amount
    def withdraw(self,amount):
        self.__balance=self.__balance-amount
print("enter name:")
p=input()
print("enter mobile number:")
q=int(input())
print("enter Dath of Birth:")
r=(input())
print("enter Account number:")
s=int(input())
print("enter Amount to deposite:")
t=int(input())
z=[p,q,r,s,t]
amount=1000
bank=bank_account(p,q,r,s,t)
# Out:
# enter name:
#  ghj
# enter mobile number:
#  45678
# enter Dath of Birth:
#  567890
# enter Account number:
#  234567
# enter Amount to deposite:
#  1000

# %%
bank.detail()
# Out:
# ('ghj', 45678, '567890', 234567, 1000)

# %%
bank.add(1000)

# %%
bank.detail()
# Out:
# ('ghj', 45678, '567890', 234567, 3000)

# %%
bank.withdraw(500)

# %%
bank.detail()
# Out:
# ('ghj', 45678, '567890', 234567, 2500)
